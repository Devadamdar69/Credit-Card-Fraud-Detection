# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score 
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, matthews_corrcoef
from sklearn.metrics import confusion_matrix
scaler=StandardScaler()

# %%
df= pd.read_csv('./creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# No null record in data set

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df1=pd.read_csv('./creditcard.csv')

# %%
fraud=df1[df1['Class']==1]
non_fraud=df1[df1['Class']==0]
len(fraud), len(non_fraud)
# Out:
# (492, 284315)

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
non_fraud.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# ## Plotting the Correlation Matrix

# %%
corrmat = df1.corr()
fig= plt.figure(figsize=(12,8))
sns.heatmap(corrmat,vmax=0.8, square=True)
plt.show()

# %%
df['Normalized_amount']= scaler.fit_transform(df["Amount"].values.reshape(-1,1))

# %%
df.drop(["Amount","Time"],inplace=True, axis=1)
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Class  Normalized_amount
# ...

# %%
#for all independent variable
x=df.drop(["Class"],axis=1)

y=df["Class"]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.3, random_state=1)

# %%
xtrain.shape
# Out:
# (199364, 29)

# %%
xtest.shape
# Out:
# (85443, 29)

# %%
rf1 = RandomForestClassifier(n_estimators = 10)

# %%
rf1.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
prediction_rf = rf1.predict(xtest)

# %%
rf_score = rf1.score(xtest,ytest)*100
rf_score
# Out:
# 99.94148145547324

# %%
outliers=len(fraud)
error=(prediction_rf != ytest).sum()

# %%
accuracy = accuracy_score(ytest, prediction_rf)
accuracy
# Out:
# 0.9994148145547324

# %%
precision = precision_score(ytest, prediction_rf)
precision
# Out:
# np.float64(0.9047619047619048)

# %%
recalling = recall_score(ytest, prediction_rf)
recalling
# Out:
# np.float64(0.7037037037037037)

# %%
f1= f1_score(ytest, prediction_rf)
f1
# Out:
# np.float64(0.7916666666666666)

# %%
MCC = matthews_corrcoef(ytest, prediction_rf)
MCC
# Out:
# np.float64(0.7976518394333061)

# %% [markdown]
# # Visualizing the Confusion Matrix

# %%
LABELS = ['Normal', 'Fraud']
conf_mat= confusion_matrix(ytest, prediction_rf)
plt.figure(figsize=(10,10))

sns.heatmap(conf_mat, xticklabels= LABELS, yticklabels= LABELS, annot=True, fmt='d')

plt.title("Confusion Matrix")
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()
